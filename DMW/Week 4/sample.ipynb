# %%
import pandas as pd
import json

data = []
with open('sample.jsonl', 'r') as f:
        for line in f:
            data.append(json.loads(line))
        df = pd.DataFrame(data)

df
# Out:
#       paper_id                                 _pdf_hash  \
# 0     77499681  11f281316fe4638843a83cf559ce4f60aade00f8
# 1     94550656  42b3e1bd9c4740192f22d8725d470218e86301c8
# 2     94551239  b355fc0f19e1945bcb585b0f696da8b01aa4578f
# 3     94551546  9bf1cb19041b8ddfca7aeccc9d2f7689c8aa1c7e
# 4     94552339  7dc1bf397fb5aae2fa07e2697ba6f0237a411bb6
# ..         ...                                       ...
# 198  123621809  be029ed4e16f9eaa16abda8a4135b1fc2552ebb5
# 199  123624411  abf6155312bd8ab8751a98e5f8ff5e1a90c56c31
# 200  123624889  783f2a7c312fb742b1c78623f1f7e2aa10a717df
# 201  123625503  d0b77ef879fd54944e9fca0bee8acb9aa93d5980
# 202  123625563  f7150c50c024431803c97aee3bd30657e935b834
#
#                                               abstract  \
# 0    [{'section': 'Abstract', 'text': 'The purpose ...
# 1                                                   []
# 2                                                   []
# ...
